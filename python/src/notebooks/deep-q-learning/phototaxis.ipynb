# %%
import sys

sys.path.append("../..")

# %%
import nest_asyncio

nest_asyncio.apply()

import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices("GPU")
if gpus:
    tf.config.experimental.set_memory_growth(gpus[0], True)

# %%
from training.dqnetwork import DQNetwork

# %%
from environment.deepqlearning.phototaxis_env import PhototaxisEnv
from utils.reader import get_yaml_path, read_file

# %% [markdown]
# ## Connect to Simulator

# %%
server_address = "localhost:50056"
client_name = "PhototaxisDQNClient"
env = PhototaxisEnv(server_address, client_name)
env.connect_to_client()
# Out:
# 2025-12-03 15:39:25,227 — INFO — ✓ Connected to localhost:50056

# %% [markdown]
# ## Load Configurations

# %%
import glob
import os

# Load all phototaxis configuration files
config_dir = os.path.join(
    "..", "..", "scripts", "resources", "generated", "phototaxis", "envs1"
)
config_files = sorted(glob.glob(os.path.join(config_dir, "environment_*.yml")))

configs = []
for config_file in config_files:
    configs.append(read_file(config_file))

print(f"Loaded {len(configs)} configuration files")

# Initialize with the first config
env.init(configs[0])

# Reset environment to ensure agents are properly initialized
_ = env.reset()
# Out:
# Loaded 300 configuration files

# %% [markdown]
# ## Network Architecture

# %%
neuron_count_per_hidden_layer = [128, 64]

# %% [markdown]
# ## Hyperparameters

# %%
episode_count = 1000  # Total number of training episodes
episode_max_steps = 2000  # Maximum number of steps per episode

replay_memory_max_size = 100000  # Maximum number of transitions in replay memory
replay_memory_init_size = 10000  # Initial replay memory size before training starts
batch_size = 512  # Mini-batch size for training

step_per_update = 4  # Number of steps between action model updates
step_per_update_target_model = 1000  # Number of steps between target model updates

max_epsilon = 1.0  # Initial exploration probability
min_epsilon = 0.01  # Minimum exploration probability
epsilon_decay = 0.0002  # Decay rate for exploration probability

gamma = 0.99  # Discount factor for future rewards

moving_avg_window_size = 20  # Window size for moving average of rewards
moving_avg_stop_thr = 100  # Threshold for early stopping based on moving average

# %% [markdown]
# ## Create Agent

# %%
from agent.scala_dqagent import DQAgent

agent1 = DQAgent(
    env,
    agent_id="00000000-0000-0000-0000-000000000001",
    action_model=DQNetwork(
        env.observation_space.shape,
        neuron_count_per_hidden_layer,
        env.action_space.n,
        summary=True,
    ),
    target_model=DQNetwork(
        env.observation_space.shape,
        neuron_count_per_hidden_layer,
        env.action_space.n,
        summary=False,
    ),
    epsilon_max=max_epsilon,
    epsilon_min=min_epsilon,
    gamma=gamma,
    replay_memory_max_size=replay_memory_max_size,
    replay_memory_init_size=replay_memory_init_size,
    batch_size=batch_size,
    step_per_update=step_per_update,
    step_per_update_target_model=step_per_update_target_model,
    moving_avg_window_size=moving_avg_window_size,
    moving_avg_stop_thr=moving_avg_stop_thr,
    episode_max_steps=episode_max_steps,
    episodes=episode_count,
)

agents = [agent1]
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         2,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,757 (42.02 KB)
#  Trainable params: 10,757 (42.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training

# %%
import time
from training.multi_agent_dqlearning import DQLearning

train_start_time = time.time()

trainer = DQLearning(
    env,
    agents,
    configs,
    episode_count=episode_count,
    episode_max_steps=episode_max_steps,
)
# train_rewards = trainer.simple_dqn_training()

# train_finish_time = time.time()
# train_elapsed_time = train_finish_time - train_start_time
# train_avg_episode_time = train_elapsed_time / episode_count

# print(f"Train time: {train_elapsed_time / 60.0:.1f}m [{train_avg_episode_time:.1f}s]")

# %% [markdown]
# ## Evaluation with Visualization
#
# Watch the trained agent perform phototaxis in real-time.
#
# **Keyboard Controls:**
# - `ESC/Q`: Quit
# - `SPACE`: Pause/Resume
# - `↑/↓`: Adjust FPS

# %%
trainer.play_with_pygame(episodes=1, fps=90)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 trainer.play_with_pygame(episodes=1, fps=90)
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\src\notebooks\deep-q-learning\../..\training\multi_agent_dqlearning.py:212, in DQLearning.play_with_pygame(self, episodes, fps, render_scale)
#     208     pygame.time.wait(100)
#     209     continue
#     210 actions = {
#     211     agent.id: np.argmax(
# --> 212         agent.action_model.predict(
#     213             states[agent.id][np.newaxis], verbose=0
#     214         )[0]
#     215     )
#     216     for agent in self.agents
#     217 }
#     219 next_states, rewards, terminateds, truncateds, _ = self.env.step(
#     220     actions
#     221 )
#     222 dones = {
#     223     agent.id: terminateds[agent.id] or truncateds[agent.id]
#     224     for agent in self.agents
#     225 }
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:505, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     500 @traceback_utils.filter_traceback
#     501 def predict(
#     502     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     503 ):
#     504     # Create an iterator that yields batches of input data.
# --> 505     epoch_iterator = TFEpochIterator(
#     506         x=x,
#     507         batch_size=batch_size,
#     508         steps_per_epoch=steps,
#     509         shuffle=False,
#     510         distribute_strategy=self.distribute_strategy,
#     511         steps_per_execution=self.steps_per_execution,
#     512     )
#     514     # Container that configures and calls callbacks.
#     515     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:728, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     726 super().__init__(*args, **kwargs)
#     727 self._distribute_strategy = distribute_strategy
# --> 728 dataset = self.data_adapter.get_tf_dataset()
#     729 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     730     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     731         dataset
#     732     )
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:140, in ArrayDataAdapter.get_tf_dataset(self)
#     133     return indices
#     135 # We prefetch a single element. Computing large permutations can take
#     136 # quite a while so we don't want to wait for prefetching over an epoch
#     137 # boundary to trigger the next permutation. On the other hand, too many
#     138 # simultaneous shuffles can contend on a hardware level and degrade all
#     139 # performance.
# --> 140 indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     142 def slice_batch_indices(indices):
#     143     """Convert a Tensor of indices into a dataset of batched indices.
#     144
#     145     This step can be accomplished in several ways. The most natural is
#    (...)    157         A Dataset of batched indices.
#     158     """
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2341, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, synchronous, use_unbounded_threadpool, name)
#    2336 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2337 # dataset_ops).
#    2338 # pylint: disable=g-import-not-at-top,protected-access
#    2339 from tensorflow.python.data.ops import map_op
# -> 2341 return map_op._map_v2(
#    2342     self,
#    2343     map_func,
#    2344     num_parallel_calls=num_parallel_calls,
#    2345     deterministic=deterministic,
#    2346     synchronous=synchronous,
#    2347     use_unbounded_threadpool=use_unbounded_threadpool,
#    2348     name=name,
#    2349 )
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\tensorflow\python\data\ops\map_op.py:43, in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, synchronous, use_unbounded_threadpool, name)
#      38   if deterministic is not None and not debug_mode.DEBUG_MODE:
#      39     warnings.warn(
#      40         "The `deterministic` argument has no effect unless the "
#      41         "`num_parallel_calls` argument is specified."
#      42     )
# ---> 43   return _MapDataset(
#      44       input_dataset,
#      45       map_func,
#      46       preserve_cardinality=True,
#      47       force_synchronous=False if synchronous is None else synchronous,
#      48       name=name,
#      49   )
#      50 else:
#      51   if synchronous:
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\tensorflow\python\data\ops\map_op.py:157, in _MapDataset.__init__(self, input_dataset, map_func, force_synchronous, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     155 self._use_inter_op_parallelism = use_inter_op_parallelism
#     156 self._preserve_cardinality = preserve_cardinality
# --> 157 self._map_func = structured_function.StructuredFunctionWrapper(
#     158     map_func,
#     159     self._transformation_name(),
#     160     dataset=input_dataset,
#     161     use_legacy_function=use_legacy_function)
#     162 self._force_synchronous = force_synchronous
#     163 self._name = name
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1256, in Function.get_concrete_function(self, *args, **kwargs)
#    1254 def get_concrete_function(self, *args, **kwargs):
#    1255   # Implements PolymorphicFunction.get_concrete_function.
# -> 1256   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1257   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1258   return concrete
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1226, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1224   if self._variable_creation_config is None:
#    1225     initializers = []
# -> 1226     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1227     self._initialize_uninitialized_variables(initializers)
#    1229 if self._created_variables:
#    1230   # In this case we have created variables on the first call, so we run the
#    1231   # version which is guaranteed to never create variables.
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:340, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     331 output_type = trace_type.from_value(
#     332     traced_func_graph.structured_outputs, type_context
#     333 )
#     334 traced_func_type = function_type_lib.FunctionType(
#     335     function_type.parameters.values(),
#     336     traced_func_graph.function_captures.capture_types,
#     337     return_annotation=output_type,
#     338 )
# --> 340 concrete_function = concrete_function_lib.ConcreteFunction.from_func_graph(
#     341     traced_func_graph,
#     342     traced_func_type,
#     343     tracing_options.attributes,
#     344     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     345     # scope. This is not the default behavior since it gets used in some
#     346     # places (like Keras) where the FuncGraph lives longer than the
#     347     # ConcreteFunction.
#     348     shared_func_graph=False,
#     349 )
#     350 _set_arg_keywords(concrete_function)
#     351 transform.call_concrete_function_callbacks(concrete_function)
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1075, in ConcreteFunction.from_func_graph(cls, graph, function_type, attrs, shared_func_graph)
#    1073 @classmethod
#    1074 def from_func_graph(cls, graph, function_type, attrs, shared_func_graph=True):
# -> 1075   atomic_fn = atomic_function.from_func_graph(
#    1076       _inference_name(graph.name), graph, attrs, function_type
#    1077   )
#    1078   return ConcreteFunction(atomic_fn, shared_func_graph=shared_func_graph)
#
# File ~\Github\university\first_year\second_semester\PPS-22-srs\python\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:557, in from_func_graph(name, graph, attrs, function_type, overwrite)
#     555 for attr_name, attr_value in attrs.items():
#     556   serialized = attr_value.SerializeToString()
# --> 557   pywrap_tf_session.TF_FunctionSetAttrValueProto(
#     558       fn, compat.as_str(attr_name), serialized
#     559   )
#     561 name = compat.as_bytes(name)
#     562 bound_context = context.context()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Save Trained Models

# %%
# import os
#
# # Create checkpoints directory if it doesn't exist
# os.makedirs("checkpoints", exist_ok=True)
#
# # Save the trained models
# for i, agent in enumerate(agents):
#     agent.action_model.save(f"checkpoints/phototaxis_dqn_agent{i}_action_model.keras")
#     agent.target_model.save(f"checkpoints/phototaxis_dqn_agent{i}_target_model.keras")
#     print(f"Agent {i} models saved successfully")

# %% [markdown]
# ## Load Pre-trained Models (Optional)

# %%
for i, agent in enumerate(agents):
    agent.action_model = tf.keras.models.load_model(
        f"../../scripts/checkpoints/002V2photo/photo_ep8093/action_model.keras"
    )
    agent.target_model = tf.keras.models.load_model(
        f"../../scripts/checkpoints/002V2photo/photo_ep7435/target_model.keras"
    )
    print(f"Agent {i} models loaded successfully")


# OTTIMo
# for i, agent in enumerate(agents):
#     agent.action_model = tf.keras.models.load_model(
#         f"../../scripts/checkpoints/002photo/photo_ep4614/action_model.keras"
#     )
#     agent.target_model = tf.keras.models.load_model(
#         f"../../scripts/checkpoints/002Photo/photo_ep4614/target_model.keras"
#     )
#     print(f"Agent {i} models loaded successfully")

    #
    # for i, agent in enumerate(agents):
    #     agent.action_model = tf.keras.models.load_model(
    #         f"../../scripts/checkpoints/004photo/photo_ep1533/action_model.keras"
    #     )
    # agent.target_model = tf.keras.models.load_model(
    #     f"../../scripts/checkpoints/004Photo/photo_ep1533/target_model.keras"
    # )
    # print(f"Agent {i} models loaded successfully")
# Out:
# Agent 0 models loaded successfully

# %%
# Optimize models for faster inference
import tensorflow as tf

# Warm up the models (first prediction is always slower)
print("Warming up models for smooth visualization...")
for agent in agents:
    dummy_state = tf.random.normal((1,) + env.observation_space.shape)
    _ = agent.action_model(dummy_state, training=False)
    _ = agent.target_model(dummy_state, training=False)
print("✓ Models warmed up and ready!")
# Out:
# Warming up models for smooth visualization...
# ✓ Models warmed up and ready!

# %%
def play_optimized(trainer, episodes=1, fps=60, render_scale=(800, 600)):
    """Optimized visualization with smoother rendering."""
    import pygame
    import numpy as np
    import tensorflow as tf

    pygame.init()
    screen = pygame.display.set_mode(render_scale)
    pygame.display.set_caption("DQN Agent - Optimized View")
    clock = pygame.time.Clock()
    running = True
    paused = False
    current_fps = fps

    # Font setup
    font = pygame.font.Font(None, 20)

    # Pre-compile model for faster inference
    @tf.function
    def predict_action(model, state):
        return model(state, training=False)

    for ep in range(episodes):
        states, _ = trainer.env.reset()
        done = False
        total_reward = 0
        step = 0

        for agent in trainer.agents:
            agent.terminated = False

        while not done and running:
            step += 1

            # Handle events
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    running = False
                elif event.type == pygame.KEYDOWN:
                    if event.key in (pygame.K_ESCAPE, pygame.K_q):
                        running = False
                    elif event.key == pygame.K_SPACE:
                        paused = not paused
                    elif event.key == pygame.K_UP:
                        current_fps = min(240, current_fps + 10)
                    elif event.key == pygame.K_DOWN:
                        current_fps = max(10, current_fps - 10)

            if paused:
                pygame.time.wait(100)
                continue

            # Fast action selection using compiled function
            actions = {}
            for agent in trainer.agents:
                state_batch = tf.convert_to_tensor(
                    states[agent.id][np.newaxis], dtype=tf.float32
                )
                q_values = predict_action(agent.action_model, state_batch)
                actions[agent.id] = int(tf.argmax(q_values[0]).numpy())

            # Step environment
            next_states, rewards, terminateds, truncateds, _ = trainer.env.step(actions)
            dones = {
                agent.id: terminateds[agent.id] or truncateds[agent.id]
                for agent in trainer.agents
            }
            done = all(dones.values())
            total_reward += rewards[trainer.agents[0].id]
            states = next_states

            # Optimized rendering
            rgb_array = trainer.env.render()
            surface = pygame.surfarray.make_surface(np.transpose(rgb_array, (1, 0, 2)))
            surface = pygame.transform.smoothscale(
                surface, render_scale
            )  # smoothscale is faster
            screen.blit(surface, (0, 0))

            # Minimal overlay for better performance
            info_texts = [
                f"Ep: {ep + 1} | Step: {step} | Reward: {total_reward:.1f} | FPS: {current_fps}",
                "PAUSED (SPACE)" if paused else "ESC: Quit | SPACE: Pause | ↑↓: FPS",
            ]

            for i, text in enumerate(info_texts):
                color = (255, 255, 0) if paused else (255, 255, 255)
                text_surf = font.render(text, True, color, (0, 0, 0, 180))
                screen.blit(text_surf, (10, 10 + i * 25))

            pygame.display.flip()
            clock.tick(current_fps)

        print(f"Episode {ep + 1}/{episodes} - Reward: {total_reward:.2f}")

    pygame.quit()


print("✓ Optimized visualization function loaded")
# Out:
# ✓ Optimized visualization function loaded

# %%
# Test all configuration scenarios with optimized visualization
for i, config in enumerate(configs):
    if i == 30:
        break
    print()
    print("=" * 60)
    print(f"Testing Scenario {i + 1}/{len(configs)}")
    print("=" * 60)

    # Initialize environment with specific configuration
    env.init(config)

    # Use optimized visualization (smoother and faster)
    play_optimized(trainer, episodes=1, fps=60)

    import time

    time.sleep(0.3)  # Brief pause between scenarios

print()
print("✓ Finished testing all scenarios!")
# Out:
# ============================================================
# Testing Scenario 1/300
# ============================================================
# Episode 1/1 - Reward: -74.05
#
# ============================================================
# Testing Scenario 2/300
# ============================================================
# Episode 1/1 - Reward: -14.27
#
# ============================================================
# Testing Scenario 3/300
# ============================================================
# Episode 1/1 - Reward: -8.70
#
# ============================================================
# Testing Scenario 4/300
# ============================================================
# Episode 1/1 - Reward: -12.52
#
# ============================================================
# Testing Scenario 5/300
# ============================================================
# Episode 1/1 - Reward: -0.99
#
# ============================================================
# Testing Scenario 6/300
# ============================================================
# Episode 1/1 - Reward: -0.00
#
# ============================================================
# Testing Scenario 7/300
# ============================================================
# Episode 1/1 - Reward: -0.16
#
# ============================================================
# Testing Scenario 8/300
# ============================================================
# Episode 1/1 - Reward: -0.00
#
# ============================================================
# Testing Scenario 9/300
# ============================================================
# Episode 1/1 - Reward: -0.00
#
# ============================================================
# Testing Scenario 10/300
# ============================================================
# Episode 1/1 - Reward: -0.17
#
# ============================================================
# Testing Scenario 11/300
# ============================================================
# Episode 1/1 - Reward: -0.00
#
# ============================================================
# Testing Scenario 12/300
# ============================================================
# Episode 1/1 - Reward: -0.08
#
# ============================================================
# Testing Scenario 13/300
# ============================================================
# Episode 1/1 - Reward: -0.70
#
# ============================================================
# Testing Scenario 14/300
# ============================================================
# Episode 1/1 - Reward: -0.05
#
# ============================================================
# Testing Scenario 15/300
# ============================================================
# Episode 1/1 - Reward: -0.34
#
# ============================================================
# Testing Scenario 16/300
# ============================================================
# Episode 1/1 - Reward: -0.10
#
# ============================================================
# Testing Scenario 17/300
# ============================================================
# Episode 1/1 - Reward: -0.10
#
# ============================================================
# Testing Scenario 18/300
# ============================================================
# Episode 1/1 - Reward: -0.08
#
# ============================================================
# Testing Scenario 19/300
# ============================================================
# Episode 1/1 - Reward: -0.03
#
# ============================================================
# Testing Scenario 20/300
# ============================================================
# Episode 1/1 - Reward: -0.09
#
# ============================================================
# Testing Scenario 21/300
# ============================================================
# Episode 1/1 - Reward: -0.05
#
# ============================================================
# Testing Scenario 22/300
# ============================================================
# Episode 1/1 - Reward: -0.34
#
# ============================================================
# Testing Scenario 23/300
# ============================================================
# Episode 1/1 - Reward: -0.33
#
# ============================================================
# Testing Scenario 24/300
# ============================================================
# Episode 1/1 - Reward: -0.17
#
# ============================================================
# Testing Scenario 25/300
# ============================================================
# Episode 1/1 - Reward: -0.03
#
# ============================================================
# Testing Scenario 26/300
# ============================================================
# Episode 1/1 - Reward: -0.10
#
# ============================================================
# Testing Scenario 27/300
# ============================================================
# Episode 1/1 - Reward: -0.25
#
# ============================================================
# Testing Scenario 28/300
# ============================================================
# Episode 1/1 - Reward: -0.00
#
# ============================================================
# Testing Scenario 29/300
# ============================================================
# Episode 1/1 - Reward: -0.70
#
# ============================================================
# Testing Scenario 30/300
# ============================================================
# Episode 1/1 - Reward: -0.25
#
# ✓ Finished testing all scenarios!

# %% [markdown]
# ## Plot Training Rewards

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plot training rewards
plt.figure(figsize=(12, 6))
plt.plot(train_rewards, alpha=0.6, label="Episode Reward")

# Calculate and plot moving average
if len(train_rewards) > moving_avg_window_size:
    moving_avg = np.convolve(
        train_rewards,
        np.ones(moving_avg_window_size) / moving_avg_window_size,
        mode="valid",
    )
    plt.plot(
        range(moving_avg_window_size - 1, len(train_rewards)),
        moving_avg,
        "r-",
        linewidth=2,
        label=f"Moving Average (window={moving_avg_window_size})",
    )

plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("DQN Phototaxis Training Progress")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print(
    f"Average reward over last {moving_avg_window_size} episodes: {np.mean(train_rewards[-moving_avg_window_size:]):.2f}"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 6
#       4 # Plot training rewards
#       5 plt.figure(figsize=(12, 6))
# ----> 6 plt.plot(train_rewards, alpha=0.6, label="Episode Reward")
#       8 # Calculate and plot moving average
#       9 if len(train_rewards) > moving_avg_window_size:
#
# NameError: name 'train_rewards' is not defined
