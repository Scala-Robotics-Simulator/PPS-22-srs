# %%
import sys

sys.path.append("../..")

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from tqdm import trange

# %%
from environment.qlearning.obstacle_avoidance_env import ObstacleAvoidanceEnv
from utils.reader import get_yaml_path, read_file

# %%
from agent.qagent import QAgent
from training.qlearning import QLearning

# %%
import pygame
import numpy as np
# Out:
# <frozen importlib._bootstrap>:488: RuntimeWarning: Your system is avx2 capable but pygame was not built with support for it. The performance of some of your blits could be adversely affected. Consider enabling compile time detection with environment variables like PYGAME_DETECT_AVX2=1 if you are compiling without cross compilation.
# /nix/store/pwrhqv9fy9lbybjz9c1w283z234lzksr-python3-3.13.8-env/lib/python3.13/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
server_address = "localhost:50060"
client_name = "RLClient"
env = ObstacleAvoidanceEnv(server_address, client_name)
env.connect_to_client()
# Out:
# 2025-11-01 16:19:49,488 — INFO — ✓ Connected to localhost:50060

# %%
config_path = get_yaml_path("resources", "configurations", "obstacle-avoidance.yml")
config = read_file(config_path)
# print(config)

# %%
env.init(config)
# Out:
# 2025-11-01 16:19:49,725 — INFO — ✓ Initialization successful

# %%
episodes = 100
steps = 5000

# %%
agent = QAgent(env, episodes = episodes)
agentId = "00000000-0000-0000-0000-000000000001"
agents = { agentId: agent }

# %%
def run_episodes(episode_count, episode_max_steps, render = False):
    running = True
    
    if render:
        pygame.init()
        screen = pygame.display.set_mode((800, 600))
        pygame.display.set_caption(f"Q-Learning obstacle avoidance")
        clock = pygame.time.Clock()
    for _ep in trange(episode_count, desc="Training", unit="ep"):
        obs, _ = env.reset()
        done = False
        total_reward = { agentId: 0 }
        episode_history = []
        step_count = 0
        while not done and step_count < episode_max_steps:
            actions = { k: agents[k].choose_action(v, epsilon_greedy = not render) for k, v in obs.items() }
            next_obs, rewards, terminateds, truncateds, _ = env.step(actions)
            done = terminateds[agentId] or truncateds[agentId]
            if not render:
                for k, _ in next_obs.items():
                    agents[k].update_q(obs[k], actions[k], rewards[k], next_obs[k], done)
                    total_reward[k] += rewards[k]
            obs = next_obs
            if render:
                rgb_array = env.render()
                surface = pygame.surfarray.make_surface(np.transpose(rgb_array, (1, 0, 2)))
                screen.blit(surface, (0, 0))
                pygame.display.flip()
                clock.tick(60)
            step_count += 1
            if render:
                for event in pygame.event.get():
                    if event.type == pygame.QUIT:
                        running = False

            if not running:
                break
        for _, agent in agents.items():
            agent.decay_epsilon(_ep)
    if render:
        pygame.quit()

# %%
run_episodes(episodes, steps)
# Out:
# Training:  12%|███████████████████████                                                                                                                                                                         | 12/100 [00:12<01:29,  1.02s/ep]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 run_episodes(episodes, steps)
#
# Cell In[12], line 17, in run_episodes(episode_count, episode_max_steps, render)
#      15 while not done and step_count < episode_max_steps:
#      16     actions = { k: agents[k].choose_action(v, epsilon_greedy = not render) for k, v in obs.items() }
# ---> 17     next_obs, rewards, terminateds, truncateds, _ = env.step(actions)
#      18     # TODO: take other agents into consideration
#      19     done = terminateds[agentId] or truncateds[agentId]
#
# File ~/projects/PPS-22-srs/python/src/notebooks/q-learning/../../environment/abstract_env.py:103, in AbstractEnv.step(self, actions)
#      89 """Take a step in the environment with the given actions
#      90
#      91 Parameters
#    (...)     99     A tuple containing observations, rewards, terminateds, truncateds, and infos.
#     100 """
#     101 actions = self._decode_actions(actions)
# --> 103 observations, rewards, terminateds, truncateds, infos = self._run_async(
#     104     self.client.step(actions)
#     105 )
#     106 return (
#     107     self._encode_observations(observations),
#     108     rewards,
#    (...)    111     infos,
#     112 )
#
# File ~/projects/PPS-22-srs/python/src/notebooks/q-learning/../../environment/abstract_env.py:42, in AbstractEnv._run_async(self, coro)
#      40 def _run_async(self, coro):
#      41     """Helper method to run async coroutines synchronously"""
# ---> 42     return self.loop.run_until_complete(coro)
#
# File /nix/store/pwrhqv9fy9lbybjz9c1w283z234lzksr-python3-3.13.8-env/lib/python3.13/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File /nix/store/pwrhqv9fy9lbybjz9c1w283z234lzksr-python3-3.13.8-env/lib/python3.13/site-packages/nest_asyncio.py:133, in _patch_loop.<locals>._run_once(self)
#     130 curr_task = curr_tasks.pop(self, None)
#     132 try:
# --> 133     handle._run()
#     134 finally:
#     135     # restore the current task
#     136     if curr_task is not None:
#
# File /nix/store/cfapjd2rvqrpry4grb0kljnp8bvnvfxz-python3-3.13.8/lib/python3.13/asyncio/events.py:89, in Handle._run(self)
#      87 def _run(self):
#      88     try:
# ---> 89         self._context.run(self._callback, *self._args)
#      90     except (SystemExit, KeyboardInterrupt):
#      91         raise
#
# File /nix/store/cfapjd2rvqrpry4grb0kljnp8bvnvfxz-python3-3.13.8/lib/python3.13/asyncio/tasks.py:386, in Task.__wakeup(self, future)
#     378     self.__step(exc)
#     379 else:
#     380     # Don't pass the value of `future.result()` explicitly,
#     381     # as `Future.__iter__` and `Future.__await__` don't need it.
#    (...)    384     # instead of `__next__()`, which is slower for futures
#     385     # that return non-generator iterators from their `__iter__`.
# --> 386     self.__step()
#     387 self = None
#
# File /nix/store/cfapjd2rvqrpry4grb0kljnp8bvnvfxz-python3-3.13.8/lib/python3.13/asyncio/tasks.py:293, in Task.__step(self, exc)
#     291 _enter_task(self._loop, self)
#     292 try:
# --> 293     self.__step_run_and_handle_result(exc)
#     294 finally:
#     295     _leave_task(self._loop, self)
#
# File /nix/store/cfapjd2rvqrpry4grb0kljnp8bvnvfxz-python3-3.13.8/lib/python3.13/asyncio/tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     300 try:
#     301     if exc is None:
#     302         # We use the `send` method directly, because coroutines
#     303         # don't have `__iter__` and `__next__` methods.
# --> 304         result = coro.send(None)
#     305     else:
#     306         result = coro.throw(exc)
#
# File ~/projects/PPS-22-srs/python/src/notebooks/q-learning/../../rl/rl_client.py:74, in RLClient.step(self, actions)
#      71 request = rl_pb2.StepRequest(actions=actions)
#      72 response = await self.stub.Step(request)
#      73 logger.debug(
# ---> 74     f"✓ Step taken: observations={response.observations}, rewards={response.rewards}, terminateds={response.terminateds}, truncateds={response.truncateds}, infos={response.infos}"
#      75 )
#      76 return (
#      77     response.observations,
#      78     response.rewards,
#    (...)     81     response.infos,
#      82 )
#
# KeyboardInterrupt:

# %%
run_episodes(1, 10000, True)
